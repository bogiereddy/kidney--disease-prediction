# %%
d={"key":"123","key1":"234"}

# %%
d['key']
# Out:
# '123'

# %%
from box import ConfigBox

# %%
con=ConfigBox({'key':'123','key1':'234'})

# %%
con
# Out:
# ConfigBox({'key': '123', 'key1': '234'})

# %%
type(con)
# Out:
# box.config_box.ConfigBox

# %%
def get_prodict(x:int,y:int)->int:
    return x*y

# %%
get_prodict(2,3)
# Out:
# 6

# %%
get_prodict(x=2,y='3')
# Out:
# '33'

# %%
from beartype import beartype # ensure is using for runtime checking

# %%
@beartype
def get_prodict(x:int,y:int) ->int :
    return x*y

# %%
get_prodict(x=2, y=4)
# Out:
# 8

# %%
get_prodict(x=2, y='4')
# Out:
# ---------------------------------------------------------------------------
# BeartypeCallHintParamViolation            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_prodict(x=2, y='4')
#
# File <@beartype(__main__.get_prodict) at 0x22d71b24720>:46, in get_prodict(__beartype_get_violation, __beartype_conf, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# BeartypeCallHintParamViolation: Function __main__.get_prodict() parameter y='4' violates type hint <class 'int'>, as str '4' not instance of int.

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1pwWJdrv-YYVsKYevXdn_zYhbbNzxhN6X/view?usp=sharing"

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1pwWJdrv-YYVsKYevXdn_zYhbbNzxhN6X'

# %%
prefix="https://drive.google.com/uc?/export=download&id="

# %%
import gdown

url = "https://drive.google.com/file/d/1pwWJdrv-YYVsKYevXdn_zYhbbNzxhN6X/view?usp=sharing"

file_id = url.split("/")[-2]

prefix = "https://drive.google.com/uc?/export=download&id="

gdown.download(prefix + file_id, "Kidney-CT-Scan-data.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1pwWJdrv-YYVsKYevXdn_zYhbbNzxhN6X
# From (redirected): https://drive.google.com/uc?id=1pwWJdrv-YYVsKYevXdn_zYhbbNzxhN6X&confirm=t&uuid=da50587e-27da-4948-a3a1-5214fb1b36cb
# To: e:\ai\deep learning project\research\Kidney-CT-Scan-data.zip
# 100%|██████████| 1.67G/1.67G [01:48<00:00, 15.4MB/s]
# 'Kidney-CT-Scan-data.zip'
